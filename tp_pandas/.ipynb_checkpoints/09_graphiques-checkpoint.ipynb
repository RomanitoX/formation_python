# %%
import pandas as pd
df = pd.read_csv("data.csv")

# %%
df.price_paid = df.price_paid.apply(lambda x: x.replace("$", ""))
df.price_paid = df.price_paid.astype(float)

# %%
df.groupby("date")["price_paid"].sum()
# Out:
# date
# 03/01/2021    216.01
# 03/02/2021    262.92
# 03/03/2021    207.17
# 03/04/2021    218.45
# 03/05/2021    215.71
# 03/06/2021    202.90
# 03/07/2021    212.56
# 03/08/2021    158.94
# 03/09/2021    210.19
# 03/10/2021    201.72
# 03/11/2021    161.38
# 03/12/2021    198.21
# 03/13/2021    216.20
# 03/14/2021    267.04
# 03/15/2021    165.82
# 03/16/2021    277.60
# 03/17/2021    203.39
# 03/18/2021    189.62
# 03/19/2021    272.92
# 03/20/2021    292.83
# 03/21/2021    231.46
# 03/22/2021    218.67
# 03/23/2021    228.32
# 03/24/2021    193.71
# 03/25/2021    194.04
# 03/26/2021    185.12
# 03/27/2021    250.63
# 03/28/2021    233.76
# 03/29/2021    226.65
# 03/30/2021    147.99
# Name: price_paid, dtype: float64

# %%
df.groupby("date")["price_paid"].sum().plot(figsize=[15, 7])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.groupby("gender")["price_paid"].sum().plot.pie(legend= True, figsize=[7 ,7])
# Out:
# <AxesSubplot:ylabel='price_paid'>

# %%
df.groupby("country")["price_paid"].sum().plot.bar(rot=45, legend=True)
# Out:
# <AxesSubplot:xlabel='country'>
